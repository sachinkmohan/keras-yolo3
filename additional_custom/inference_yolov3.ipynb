# %%
from yolo import YOLO, detect_video
import cv2

# %%
path_image = cv2.imread('street.jpg')

# %%
image = cv2.resize(path_image, (416, 416))

# %%
#import matplotlib.pyplot as plt
#plt.imshow(image)

# %%
path_weights='./model_data/yolo.h5'
path_anchors='./model_data/yolo_anchors.txt'
path_classes='./model_data/coco_classes.txt'
nb_gpu=1

# %%
yolo = YOLO(weights_path=path_weights, anchors_path=path_anchors,
                classes_path=path_classes, nb_gpu=nb_gpu)
# Out:
# model_data/yolo.h5 model, anchors, and classes loaded.
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~/virtualenv/kyolo3_tf2/lib/python3.6/site-packages/tensorflow/python/util/dispatch.py in wrapper(*args, **kwargs)
#     205     try:
# --> 206       return target(*args, **kwargs)
#     207     except (TypeError, ValueError):
#
# ~/virtualenv/kyolo3_tf2/lib/python3.6/site-packages/tensorflow/python/ops/array_ops.py in _slice_helper(tensor, slice_spec, var)
#     964   """
# --> 965   tensor = ops.convert_to_tensor(tensor)
#     966   # TODO(wangpeng): Consider supporting var
#
# ~/virtualenv/kyolo3_tf2/lib/python3.6/site-packages/tensorflow/python/profiler/trace.py in wrapped(*args, **kwargs)
#     162           return func(*args, **kwargs)
# --> 163       return func(*args, **kwargs)
#     164
#
# ~/virtualenv/kyolo3_tf2/lib/python3.6/site-packages/tensorflow/python/framework/ops.py in convert_to_tensor(value, dtype, name, as_ref, preferred_dtype, dtype_hint, ctx, accepted_result_types)
#    1565     if ret is None:
# -> 1566       ret = conversion_func(value, dtype=dtype, name=name, as_ref=as_ref)
#    1567
#
# ~/virtualenv/kyolo3_tf2/lib/python3.6/site-packages/tensorflow/python/framework/constant_op.py in _constant_tensor_conversion_function(v, dtype, name, as_ref)
#     345   _ = as_ref
# --> 346   return constant(v, dtype=dtype, name=name)
#     347
#
# ~/virtualenv/kyolo3_tf2/lib/python3.6/site-packages/tensorflow/python/framework/constant_op.py in constant(value, dtype, shape, name)
#     271   return _constant_impl(value, dtype, shape, name, verify_shape=False,
# --> 272                         allow_broadcast=True)
#     273
#
# ~/virtualenv/kyolo3_tf2/lib/python3.6/site-packages/tensorflow/python/framework/constant_op.py in _constant_impl(value, dtype, shape, name, verify_shape, allow_broadcast)
#     282         return _constant_eager_impl(ctx, value, dtype, shape, verify_shape)
# --> 283     return _constant_eager_impl(ctx, value, dtype, shape, verify_shape)
#     284
#
# ~/virtualenv/kyolo3_tf2/lib/python3.6/site-packages/tensorflow/python/framework/constant_op.py in _constant_eager_impl(ctx, value, dtype, shape, verify_shape)
#     307   """Creates a constant on the current device."""
# --> 308   t = convert_to_eager_tensor(value, ctx, dtype)
#     309   if shape is None:
#
# ~/virtualenv/kyolo3_tf2/lib/python3.6/site-packages/tensorflow/python/framework/constant_op.py in convert_to_eager_tensor(value, ctx, dtype)
#     105   ctx.ensure_initialized()
# --> 106   return ops.EagerTensor(value, ctx.device_name, dtype)
#     107
#
# ~/virtualenv/kyolo3_tf2/lib/python3.6/site-packages/keras/engine/keras_tensor.py in __array__(self)
#     244     raise TypeError(
# --> 245         'Cannot convert a symbolic Keras input/output to a numpy array. '
#     246         'This error may indicate that you\'re trying to pass a symbolic value '
#
# TypeError: Cannot convert a symbolic Keras input/output to a numpy array. This error may indicate that you're trying to pass a symbolic value to a NumPy call, which is not supported. Or, you may be trying to pass Keras symbolic inputs/outputs to a TF API that does not register dispatching, preventing Keras from automatically converting the API call to a lambda layer in the Functional Model.
#
# During handling of the above exception, another exception occurred:
#
# InvalidArgumentError                      Traceback (most recent call last)
# ~/virtualenv/kyolo3_tf2/lib/python3.6/site-packages/tensorflow/python/framework/ops.py in _create_c_op(graph, node_def, inputs, control_inputs, op_def)
#    1879   try:
# -> 1880     c_op = pywrap_tf_session.TF_FinishOperation(op_desc)
#    1881   except errors.InvalidArgumentError as e:
#
# InvalidArgumentError: Subshape must have computed start >= end since stride is negative, but is 0 and 2 (computed from start 0 and end 9223372036854775807 over shape with rank 2 and stride-1)
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# <ipython-input-11-340e712223db> in <module>
#       1 yolo = YOLO(weights_path=path_weights, anchors_path=path_anchors,
# ----> 2                 classes_path=path_classes, nb_gpu=nb_gpu)
#
# ~/git/Thesis_Repos/test/keras-yolo3_tf2/yolo.py in __init__(self, **kwargs)
#      39         self.class_names = self._get_class()
#      40         self.anchors = self._get_anchors()
# ---> 41         self.boxes, self.scores, self.classes = self.generate()
#      42
#      43     def _get_class(self):
#
# ~/git/Thesis_Repos/test/keras-yolo3_tf2/yolo.py in generate(self)
#      95         boxes, scores, classes = yolo_eval(self.yolo_model.output, self.anchors,
#      96                 len(self.class_names), self.input_image_shape,
# ---> 97                 score_threshold=self.score, iou_threshold=self.iou)
#      98
#      99         return boxes, scores, classes
#
# ~/git/Thesis_Repos/test/keras-yolo3_tf2/yolo3/model.py in yolo_eval(yolo_outputs, anchors, num_classes, image_shape, max_boxes, score_threshold, iou_threshold)
#     198     for l in range(num_layers):
#     199         _boxes, _box_scores = yolo_boxes_and_scores(yolo_outputs[l],
# --> 200             anchors[anchor_mask[l]], num_classes, input_shape, image_shape)
#     201         boxes.append(_boxes)
#     202         box_scores.append(_box_scores)
#
# ~/git/Thesis_Repos/test/keras-yolo3_tf2/yolo3/model.py in yolo_boxes_and_scores(feats, anchors, num_classes, input_shape, image_shape)
#     175     '''Process Conv layer output'''
#     176     box_xy, box_wh, box_confidence, box_class_probs = yolo_head(feats,
# --> 177         anchors, num_classes, input_shape)
#     178     boxes = yolo_correct_boxes(box_xy, box_wh, input_shape, image_shape)
#     179     boxes = K.reshape(boxes, [-1, 4])
#
# ~/git/Thesis_Repos/test/keras-yolo3_tf2/yolo3/model.py in yolo_head(feats, anchors, num_classes, input_shape, calc_loss)
#     136
#     137     # Adjust preditions to each spatial grid point and anchor size.
# --> 138     box_xy = (K.sigmoid(feats[..., :2]) + grid) / tf.cast(grid_shape[::-1], feats.dtype)
#     139     box_wh = K.exp(feats[..., 2:4]) * anchors_tensor / tf.cast(input_shape[::-1], feats.dtype)
#     140     box_confidence = K.sigmoid(feats[..., 4:5])
#
# ~/virtualenv/kyolo3_tf2/lib/python3.6/site-packages/tensorflow/python/util/dispatch.py in wrapper(*args, **kwargs)
#     208       # Note: convert_to_eager_tensor currently raises a ValueError, not a
#     209       # TypeError, when given unexpected types.  So we need to catch both.
# --> 210       result = dispatch(wrapper, args, kwargs)
#     211       if result is not OpDispatcher.NOT_SUPPORTED:
#     212         return result
#
# ~/virtualenv/kyolo3_tf2/lib/python3.6/site-packages/tensorflow/python/util/dispatch.py in dispatch(op, args, kwargs)
#     120   """
#     121   for dispatcher in getattr(op, DISPATCH_ATTR):
# --> 122     result = dispatcher.handle(args, kwargs)
#     123     if result is not OpDispatcher.NOT_SUPPORTED:
#     124       return result
#
# ~/virtualenv/kyolo3_tf2/lib/python3.6/site-packages/keras/layers/core.py in handle(self, args, kwargs)
#    1559         isinstance(x, keras_tensor.KerasTensor)
#    1560         for x in tf.nest.flatten([args, kwargs])):
# -> 1561       return SlicingOpLambda(self.op)(*args, **kwargs)
#    1562     else:
#    1563       return self.NOT_SUPPORTED
#
# ~/virtualenv/kyolo3_tf2/lib/python3.6/site-packages/keras/engine/base_layer.py in __call__(self, *args, **kwargs)
#     975     if _in_functional_construction_mode(self, inputs, args, kwargs, input_list):
#     976       return self._functional_construction_call(inputs, args, kwargs,
# --> 977                                                 input_list)
#     978
#     979     # Maintains info about the `Layer.call` stack.
#
# ~/virtualenv/kyolo3_tf2/lib/python3.6/site-packages/keras/engine/base_layer.py in _functional_construction_call(self, inputs, args, kwargs, input_list)
#    1113       # Check input assumptions set after layer building, e.g. input shape.
#    1114       outputs = self._keras_tensor_symbolic_call(
# -> 1115           inputs, input_masks, args, kwargs)
#    1116
#    1117       if outputs is None:
#
# ~/virtualenv/kyolo3_tf2/lib/python3.6/site-packages/keras/engine/base_layer.py in _keras_tensor_symbolic_call(self, inputs, input_masks, args, kwargs)
#     846       return tf.nest.map_structure(keras_tensor.KerasTensor, output_signature)
#     847     else:
# --> 848       return self._infer_output_signature(inputs, args, kwargs, input_masks)
#     849
#     850   def _infer_output_signature(self, inputs, args, kwargs, input_masks):
#
# ~/virtualenv/kyolo3_tf2/lib/python3.6/site-packages/keras/engine/base_layer.py in _infer_output_signature(self, inputs, args, kwargs, input_masks)
#     892                               build_graph=False)
#     893       outputs = tf.nest.map_structure(
# --> 894           keras_tensor.keras_tensor_from_tensor, outputs)
#     895
#     896     if hasattr(self, '_set_inputs') and not self.inputs:
#
# ~/virtualenv/kyolo3_tf2/lib/python3.6/site-packages/tensorflow/python/util/nest.py in map_structure(func, *structure, **kwargs)
#     867
#     868   return pack_sequence_as(
# --> 869       structure[0], [func(*x) for x in entries],
#     870       expand_composites=expand_composites)
#     871
#
# ~/virtualenv/kyolo3_tf2/lib/python3.6/site-packages/tensorflow/python/util/nest.py in <listcomp>(.0)
#     867
#     868   return pack_sequence_as(
# --> 869       structure[0], [func(*x) for x in entries],
#     870       expand_composites=expand_composites)
#     871
#
# ~/virtualenv/kyolo3_tf2/lib/python3.6/site-packages/keras/engine/keras_tensor.py in keras_tensor_from_tensor(tensor)
#     582       break
#     583
# --> 584   out = keras_tensor_cls.from_tensor(tensor)
#     585
#     586   if hasattr(tensor, '_keras_mask'):
#
# ~/virtualenv/kyolo3_tf2/lib/python3.6/site-packages/keras/engine/keras_tensor.py in from_tensor(cls, tensor)
#     158         # * cases where int32 tensors too large to represent shapes are
#     159         #   manipulated to a smaller size before being used as a shape tensor
# --> 160         inferred_value = tf.ones(shape=tensor).shape
#     161         if inferred_value.dims:
#     162           inferred_value = inferred_value.as_list()
#
# ~/virtualenv/kyolo3_tf2/lib/python3.6/site-packages/tensorflow/python/util/dispatch.py in wrapper(*args, **kwargs)
#     204     """Call target, and fall back on dispatchers if there is a TypeError."""
#     205     try:
# --> 206       return target(*args, **kwargs)
#     207     except (TypeError, ValueError):
#     208       # Note: convert_to_eager_tensor currently raises a ValueError, not a
#
# ~/virtualenv/kyolo3_tf2/lib/python3.6/site-packages/tensorflow/python/ops/array_ops.py in ones(shape, dtype, name)
#    3226     if not shape._shape_tuple():
#    3227       shape = reshape(shape, [-1])  # Ensure it's a vector
# -> 3228     output = fill(shape, constant(one, dtype=dtype), name=name)
#    3229   assert output.dtype.base_dtype == dtype
#    3230   return output
#
# ~/virtualenv/kyolo3_tf2/lib/python3.6/site-packages/tensorflow/python/util/dispatch.py in wrapper(*args, **kwargs)
#     204     """Call target, and fall back on dispatchers if there is a TypeError."""
#     205     try:
# --> 206       return target(*args, **kwargs)
#     207     except (TypeError, ValueError):
#     208       # Note: convert_to_eager_tensor currently raises a ValueError, not a
#
# ~/virtualenv/kyolo3_tf2/lib/python3.6/site-packages/tensorflow/python/ops/array_ops.py in fill(dims, value, name)
#     238   @end_compatibility
#     239   """
# --> 240   result = gen_array_ops.fill(dims, value, name=name)
#     241   tensor_util.maybe_set_static_shape(result, dims)
#     242   return result
#
# ~/virtualenv/kyolo3_tf2/lib/python3.6/site-packages/tensorflow/python/ops/gen_array_ops.py in fill(dims, value, name)
#    3376   # Add nodes to the TensorFlow graph.
#    3377   _, _, _op, _outputs = _op_def_library._apply_op_helper(
# -> 3378         "Fill", dims=dims, value=value, name=name)
#    3379   _result = _outputs[:]
#    3380   if _execute.must_record_gradient():
#
# ~/virtualenv/kyolo3_tf2/lib/python3.6/site-packages/tensorflow/python/framework/op_def_library.py in _apply_op_helper(op_type_name, name, **keywords)
#     748       op = g._create_op_internal(op_type_name, inputs, dtypes=None,
#     749                                  name=scope, input_types=input_types,
# --> 750                                  attrs=attr_protos, op_def=op_def)
#     751
#     752     # `outputs` is returned as a separate return value so that the output
#
# ~/virtualenv/kyolo3_tf2/lib/python3.6/site-packages/tensorflow/python/framework/func_graph.py in _create_op_internal(self, op_type, inputs, dtypes, input_types, name, attrs, op_def, compute_device)
#     599     return super(FuncGraph, self)._create_op_internal(  # pylint: disable=protected-access
#     600         op_type, captured_inputs, dtypes, input_types, name, attrs, op_def,
# --> 601         compute_device)
#     602
#     603   def capture(self, tensor, name=None, shape=None):
#
# ~/virtualenv/kyolo3_tf2/lib/python3.6/site-packages/tensorflow/python/framework/ops.py in _create_op_internal(self, op_type, inputs, dtypes, input_types, name, attrs, op_def, compute_device)
#    3567           input_types=input_types,
#    3568           original_op=self._default_original_op,
# -> 3569           op_def=op_def)
#    3570       self._create_op_helper(ret, compute_device=compute_device)
#    3571     return ret
#
# ~/virtualenv/kyolo3_tf2/lib/python3.6/site-packages/tensorflow/python/framework/ops.py in __init__(self, node_def, g, inputs, output_types, control_inputs, input_types, original_op, op_def)
#    2040         op_def = self._graph._get_op_def(node_def.op)
#    2041       self._c_op = _create_c_op(self._graph, node_def, inputs,
# -> 2042                                 control_input_ops, op_def)
#    2043       name = compat.as_str(node_def.name)
#    2044
#
# ~/virtualenv/kyolo3_tf2/lib/python3.6/site-packages/tensorflow/python/framework/ops.py in _create_c_op(graph, node_def, inputs, control_inputs, op_def)
#    1881   except errors.InvalidArgumentError as e:
#    1882     # Convert to ValueError for backwards compatibility.
# -> 1883     raise ValueError(str(e))
#    1884
#    1885   return c_op
#
# ValueError: Subshape must have computed start >= end since stride is negative, but is 0 and 2 (computed from start 0 and end 9223372036854775807 over shape with rank 2 and stride-1)

# %%
image_pred, pred_items = yolo.detect_image(image)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-8-9fc0bf377947> in <module>
# ----> 1 image_pred, pred_items = yolo.detect_image(image)
#
# NameError: name 'yolo' is not defined
